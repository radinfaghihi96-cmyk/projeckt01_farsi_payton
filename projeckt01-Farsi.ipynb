# %%
name=input("اسمت رو بگو")
print(name)
# Out:
# رادین

# %%
LastName=input("فامیلیت روبگو")
print(LastName)
# Out:
# فقیهی

# %%
sen=input("سنت رو بگو")
print(sen)
# Out:
# 9

# %%
city=input("شهرت رو بگو")
print(city)
# Out:
# تهران

# %%
Email=input("ایمیل خود را وارد کنید")
print(Email)
# Out:
# radinfaghihi96@gmail.com

# %%
Telephone=input("شماره موبایل خود را وارد کنید")
print(Telephone)
# Out:
# 09129301018

# %%
Address=input("آدرس خود را وارد کنید")
print(Address)
# Out:
# ایران_تهران
