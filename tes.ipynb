# %%
adad1=123
adad2=132
print(adad1+adad2)

# %%
adad1=123
adad2=132
print(adad1*adad2)

# %%
adad1=123
adad2=132
print(adad1/adad2)

# %%
adad1=123
adad2=132
print(adad1-adad2)

# %%
def average_of_three(a,b,c):
     summ=a+b+c
     min=summ-3
     return min
print(average_of_three(100,200,300))
print(average_of_three(3,6,9))

# %%
def average_of_three(a,b,c):
     summ=a+b+c
     min=summ/3
     return min
print(average_of_three(100,200,300))
print(average_of_three(3,6,9))

# %%
def average_of_three(a,b,c):
     summ=a+b+c
     min=summ*3
     return min
print(average_of_three(100,200,300))
print(average_of_three(3,6,9))

# %%
def average_of_three(a,b,c):
     summ=a+b+c
     min=summ+3
     return min
print(average_of_three(100,200,300))
print(average_of_three(3,6,9))
